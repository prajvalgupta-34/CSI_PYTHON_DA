# %%
"""SUBMISSION LINK ->https://drive.google.com/drive/folders/1GN2dXvlYY31dVghx8qCTYBWeXbG8B2t7"""
# Out:
# 'SUBMISSION LINK ->https://drive.google.com/drive/folders/1GN2dXvlYY31dVghx8qCTYBWeXbG8B2t7'

# %%
"""Q1)You are cleaning up the registration data for the new CSI SIG members. Write a script 
that takes a variable member_name = " divyansh sharma ". Use built-in string methods to remove the extra
 spaces at the beginning and end,
 convert the name to Title Case (Divyansh Sharma), and print the clean result."""
# Out:
# 'Q1)You are cleaning up the registration data for the new CSI SIG members. Write a script \nthat takes a variable member_name = " divyansh sharma ". Use built-in string methods to remove the extra\n spaces at the beginning and end,\n convert the name to Title Case (Divyansh Sharma), and print the clean result.'

# %%
"""Q@)Your team is tracking time for a hackathon. Create a variable hours_left and assign it
 the string value "48". Convert this string into an integer, multiply it by 60 to calculate the total 
 minutes remaining, and print the final value."""
# Out:
# 'Q@)Your team is tracking time for a hackathon. Create a variable hours_left and assign it\n the string value "48". Convert this string into an integer, multiply it by 60 to calculate the total \n minutes remaining, and print the final value.'

# %%
"""Q3) You are monitoring the health of a local server. Write a single boolean 
expression that checks if a variable server_ping is between 20 and 50 milliseconds (inclusive).
 Print the result (True or False)."""
# Out:
# 'Q3) You are monitoring the health of a local server. Write a single boolean \nexpression that checks if a variable server_ping is between 20 and 50 milliseconds (inclusive).\n Print the result (True or False).'

# %%
"""Q4. You are managing the attendance list for today’s Python SIG. Create a list called attendees = ["Aarav", "Neha", "Rohan"].
- Add "Divyansh" to the end of the list.
- Insert "Ryan" at the beginning (index 0).
- Remove the last person from the list.
Print the final list."""
# Out:
# 'Q4. You are managing the attendance list for today’s Python SIG. Create a list called attendees = ["Aarav", "Neha", "Rohan"].\n- Add "Divyansh" to the end of the list.\n- Insert "Ryan" at the beginning (index 0).\n- Remove the last person from the list.\nPrint the final list.'

# %%
"""Q5. You are analyzing the skills of a hackathon participant. Create a dictionary 
coder = {"name": "Priya", "python_score": 90}. Use the .get() method to retrieve "docker_score". 
If it doesn't exist, return "Not Attempted"."""
# Out:
# 'Q5. You are analyzing the skills of a hackathon participant. Create a dictionary \ncoder = {"name": "Priya", "python_score": 90}. Use the .get() method to retrieve "docker_score". \nIf it doesn\'t exist, return "Not Attempted".'

# %%
"""Q6. You are writing an automated script to check GitHub repositories. Create a variable total_commits = 3. Write an if/else statement:
- If commits are less than 5, print "Needs more work before merging".
- Otherwise, print "Ready for code review"""
# Out:
# 'Q6. You are writing an automated script to check GitHub repositories. Create a variable total_commits = 3. Write an if/else statement:\n- If commits are less than 5, print "Needs more work before merging".\n- Otherwise, print "Ready for code review'

# %%
"""Q7. You are building an alert system for your "Predictive Sky-X" project. Create a variable wind_speed.
 Write an if/elif/else ladder:
- If wind speed > 120, print "Category 1 Hurricane Warning".
- If wind speed is between 70 and 120 (inclusive), print "Tropical Storm Watch".
- Otherwise, print "Clear Skies"""
# Out:
# 'Q7. You are building an alert system for your "Predictive Sky-X" project. Create a variable wind_speed.\n Write an if/elif/else ladder:\n- If wind speed > 120, print "Category 1 Hurricane Warning".\n- If wind speed is between 70 and 120 (inclusive), print "Tropical Storm Watch".\n- Otherwise, print "Clear Skies'

# %%
"""Q8. You are writing entry logic for a college tech event. Create two boolean variables: 
is_ipec_student = True and has_csi_membership = False.
Write a nested if statement:
- If they are an IPEC student, check membership.
- If they have membership, print "Full Access Granted".
- If not, print "Please pay the 50rs guest fee".
- If not an IPEC student, print "External Registration Required"""
# Out:
# 'Q8. You are writing entry logic for a college tech event. Create two boolean variables: \nis_ipec_student = True and has_csi_membership = False.\nWrite a nested if statement:\n- If they are an IPEC student, check membership.\n- If they have membership, print "Full Access Granted".\n- If not, print "Please pay the 50rs guest fee".\n- If not an IPEC student, print "External Registration Required'

# %%
"""Q9. You are validating project URLs for the "Food Fumble" hackathon. 
Create a variable github_url = "github.com/fumble-and-feast". 
Check if "fumble" is in the string. Print "Valid Repo" or "Invalid Repo"""

# %%
"""Q10. You are assigning students to pair-programming teams. Create team_size = 4. 
Check if the number is greater than 0 and divisible by 2. If true, print "Valid paired team"""

# %%
"""Q11. Define a function calculate_prize(base_amount, sponsor_bonus).
 Return the sum of the two values. Test it with calculate_prize(5000, 2000)"""

# %%
"""Q12. Define a function welcome_coder(name, event_name="Python SIG").
 Print "Welcome [name] to the [event_name]!".
 Call it once with both arguments and once with only name"""

# %%
"""Q13. Define a function check_trade(buy_price, sell_price):
- If sell_price > buy_price → return "Profit"
- If sell_price < buy_price → return "Loss"
- Else → return "Break Even""""

# %%
"""Q14. Define a function identify_type(data). Use type() and return:
- "String detected"
- "Integer detected"
- "Boolean detected""""

# %%
"""Q15. Define a function evaluate_hackathon_idea(uses_ai, feasibility_score). 
Return True only if uses_ai is True AND feasibility_score ≥ 80, else False."""
