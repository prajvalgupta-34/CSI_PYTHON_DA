# %%
"""SUBMISSION LINK->https://drive.google.com/drive/folders/1q-9rVOAKE-mTWM0OMvmhalwlro4NIBIb?usp=drive_link"""

# %%
"""1.How do you standardly import the pyplot module of Matplotlib in Python?"""

# %%
"""2.What function is used to initialize a new figure window or canvas in Matplotlib?"""

# %%
"""3.How do you programmatically add a set of custom axes to a figure object by defining
\ its bounding box coordinates [left, bottom, width, height]?"""

# %%
"""4.What method is called on an axis object to generate a basic 2D line plot?"""

# %%
"""5.How do you set the main title, X-axis label, and Y-axis label on a Matplotlib plot?"""

# %%
"""6.Which functions are used to explicitly set or limit the visible range of
 values on the X-axis and Y-axis?"""

# %%
"""7.What function creates a figure 
window along with a grid of subplots in a single call (e.g., a 2x2 grid)?"""

# %%
"""8.How do you create an inset plot (a smaller set of axes nested inside a larger plot canvas)?"""

# %%
"""9.What parameter in the plot function controls the thickness (width) of the plotted line?"""

# %%
"""10.How do you change the scaling of an axis to a logarithmic scale using Matplotlib axis methods?"""

# %%
"""part 2 SEABORN"""

# %%
"""11.How do you standardly import the Seaborn data visualization library in Python?"""

# %%
"""12.Which Seaborn function is used to plot a univariate distribution of observations 
as a histogram with an optional kernel density estimate (KDE)?"""

# %%
"""13.How do you create a scatter plot combined
 with a univariate and bivariate regression fit line using Seaborn?"""

# %%
"""14.Which Seaborn function is used to draw
 box plots to show distributions with respect to categorical variables?"""

# %%
"""15.What function is used to plot rectangular data as a 
color-encoded matrix (heatmap), typically used for correlation matrices?"""

# %%
"""16.How do you set the aesthetic style and theme of
 Seaborn plots (e.g., choosing styles like whitegrid or darkgrid)?"""

# %%
"""17.Which Seaborn function creates a grid of 
subplots to map multiple pairwise bivariate distributions across a dataset?"""

# %%
"""18.What function is used to show point estimates and confidence intervals
 as rectangular bars for categorical data?"""

# %%
"""19.How can you incorporate a third categorical dimension into a relational 
plot by mapping it to marker colors or styles?"""

# %%
"""How do you draw a violin plot—which combines box plots with kernel 
density estimation—using Seaborn?"""

# %%
"""PART 3 MYSQL"""

# %%
"""1.What SQL statement is used to query 
and retrieve data from one or more database tables?,connect mysql with jupytr notebooks """

# %%
"""2.Which SQL clause is used to filter records 
that fulfill a specified conditional criterion?"""

# %%
"""3.How do you group rows that share common 
values into summary rows when using aggregate functions like SUM() or COUNT()?"""

# %%
"""4.What SQL clause is used to combine columns from multiple tables by matching a
 related column between them?"""

# %%
"""5.Which SQL clause is used to sort the result set in either ascending or descending order?"""
