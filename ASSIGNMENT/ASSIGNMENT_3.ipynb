# %%
"""SUBMISSION LINK->https://drive.google.com/drive/folders/1LsPkO18rik6e8RyJfCD08qll31x0X75k?usp=drive_link"""

# %%
"""1.Write a NumPy snippet using np.arange() and reshape() to create a 
$3 \times 3$ matrix containing values from 1 to 9, and then swap its first and second columns."""

# %%
"""2.How do you generate a single random
 floating-point number using NumPy with a fixed seed of 42? Write the code."""

# %%
"""3. Create a $4 \times 5$ matrix of random
integers between 0 and 20 using np.random.randint(). What is the syntax to find the index position
of the maximum value in the entire flattened array?"""

# %%
"""4.Write a NumPy statement to create a $4 \times 4$ identity matrix and print its data type."""

# %%
"""5.Given an array arr = np.arange(1, 11), write a command using np
.where() that replaces all odd numbers with 1 and keeps even numbers unchanged."""

# %%
"""6.Write a NumPy snippet to initialize an array of length 100 where the first 11 
elements are all replaced with the integer 5."""

# %%
"""7.Explain the difference 
in behavior and output when using np.tile([1, 2, 3], 3) versus np.repeat([1, 2, 3], 3)."""

# %%
"""8.Given an array Z = np.arange(1, 101), 
write a boolean indexing expression to extract only the numbers that are multiples of 7."""

# %%
"""9.Create two 1D NumPy arrays Z1 and Z2 of length 10. Perform element-wise division (Z1 / Z1). 
What happens if Z1 contains zeros, and how does NumPy handle np.nan comparisons?"""

# %%
"""10. Write code using np.add() with the out parameter to perform an in-place addition 
of two arrays a and b of length 9, storing the result directly inside array a.
)"""

# %%
"""Part 2: Pandas Questions (11-20"""

# %%
"""11. Using tips.csv, write Pandas code to read the file, create a new column
 named tip_percentage (calculated as $100*(tip/total bill), and
 filter out all rows where the tip percentage is greater than $25\%$."""

# %%
"""12. Using mpg.csv, write code to group the data by model_year and cylinders, and 
compute the mean values for all numeric columns. 
How do you extract a cross-section (.xs()) for cars built in year 70?"""

# %%
"""13. Using movie_scores.csv, write code to load the dataset, drop any rows 
where all elements are missing (NaN), 
and fill remaining missing values in pre_movie_score with the column's mean value."""

# %%
"""14. Using RetailSales_BeerWineLiquor.csv, load the file while automatically parsing 
the DATE column as datetime. Set 
DATE as the index, and use .resample('A').mean() to calculate and display the yearly average sales."""

# %%
"""15. Using Sales_Funnel_CRM.csv, create a pivot table using pd.pivot_table() where the index is Company
, columns is Product, and values are Licenses, filling missing cells with 0."""

# %%
"""16. Given two sample DataFrames registrations (reg_id, name) 
and logins (log_id, name), write code to perform an Outer Join on them using pd.merge(),
 making sure to handle overlapping column names with custom suffixes."""

# %%
"""17. Create a Pandas Series containing messy strings:
 messy_names = pd.Series(["andrew  ", "bo;bo", "  claire  "]). Write a chained string method expression 
(.str) to remove semicolons, strip whitespace, and capitalize each name properly."""

# %%
"""18. Using tips.csv, 
write a custom function combined with np.vectorize() (or .apply()) to categorize total_bill into tier labels
 ('$' for $<10$, '$$' for $10 <bill < 30$, and '$$$' > 30$).
 Compare the execution performance setup style shown in the notebooks."""

# %%
"""19. Using mpg.csv, write code to filter the DataFrame using .between() to find all rows where 
weight is inclusively between 2000 and 3000 pounds, and then sort the resulting subset by mpg in
 descending order."""

# %%
"""20. Using Sales_Funnel_CRM.csv, write a query using .loc or conditional 
filtering to find the row corresponding to the maximum Sale Price.
 What is the product and company name associated with this maximum sale?"""
